# %% [markdown]
# # Best neighborhood in Pittsburgh for your family

# %% [markdown]
# ***By Matthew and Arif***

# %%
from IPython.display import Image, display

url = "https://images.squarespace-cdn.com/content/v1/54bd63f8e4b0ac034b30994b/1647531288867-SPYCBL640BIFAMZI4W12/Pittsburgh-Wedding-Photographer-Pittsburgh-Senior-Photographer_2901.jpg"

display(Image(url=url))
# Out:
# <img src="https://images.squarespace-cdn.com/content/v1/54bd63f8e4b0ac034b30994b/1647531288867-SPYCBL640BIFAMZI4W12/Pittsburgh-Wedding-Photographer-Pittsburgh-Senior-Photographer_2901.jpg"/>

# %% [markdown]
# In order to upbring the quality of life for a family moving to Pittsburgh, we must first look into the crime rate, or more specifically the arrest reports going on in that certain neighborhood. Our group thought this was the best metric to start with because saftey and reassurance is the number one thing every family should look for.

# %% [markdown]
# # Metric #1: Criminal activity and saftey

# %%
from IPython.display import Image, display

url = "https://i.etsystatic.com/27443220/r/il/a24eba/3255584618/il_fullxfull.3255584618_i5po.jpg"

display(Image(url=url))
# Out:
# <img src="https://i.etsystatic.com/27443220/r/il/a24eba/3255584618/il_fullxfull.3255584618_i5po.jpg"/>

# %% [markdown]
# Public saftey often starts with law enforcement. A given data of arrest reports are shown in order to uphold which neighborhood has the least amount of crime and more importantly the least dangerous kind of crime.

# %%
#imports panda library
import pandas as pd

url = "https://data.wprdc.org/datastore/dump/e419c20c-8df4-4729-830c-e49427a656e0"

#contains arrest data
df = pd.read_csv(url)
df.head()
# Out:
#    _id               Template   Case_Number  \
# 0    1   Adult Arrest-On View  PGHP26028801
# 1    2   Adult Arrest-On View  PGHP26028801
# 2    3       Adult Arrest-302  PGHP26028803
# 3    4  Juvenile Arrest - 302  PGHP26028828
# 4    5   Adult Arrest-On View  PGHP26028804
#
#                         ArrestPerson_ID Arrest_Date  Arrest_Year Arrest_Month  \
# 0  a50bb4e9-1417-c449-66ab-08de7753d503  2026-02-28       2026.0          Feb
# 1  a50bb4e9-1417-c449-66ab-08de7753d503  2026-02-28       2026.0          Feb
# 2  fe3728d9-7382-c593-4319-08de77516c71  2026-02-28       2026.0          Feb
# 3  a480b72c-43fb-c021-c415-08de77572633  2026-02-28       2026.0          Feb
# 4  5dd0ef50-ace6-c129-2bc1-08de7758642a  2026-02-28       2026.0          Feb
#
#   Arrest_Time                                               Type  \
# 0       22:54  On-View Arrest (apprehension without a warrant...
# 1       22:54  On-View Arrest (apprehension without a warrant...
# 2       22:32  Taken Into Custody (based on a warrant and/or ...
# 3       23:17  Taken Into Custody (based on a warrant and/or ...
# 4       22:27  On-View Arrest (apprehension without a warrant...
#
#    ArrestPerson_Age  ... NIBRS_Crime_Against NIBRS_Offense_Grouping  \
# 0              25.0  ...              Person                      A
# 1              25.0  ...              Person                      A
# 2              32.0  ...             Group B                      B
# 3              13.0  ...             Group B                      B
# 4              23.0  ...              Person                      A
#
#                                    Violation    Zone   Tract    Neighborhood  \
# 0  18 2718 A1 Strangulation Basic - Applying  Zone 4  1504.0      Glen Hazel
# 1          18 2701 A1 Simple Assault-General  Zone 4  1504.0      Glen Hazel
# 2                            302 302 Warrant  Zone 1  2615.0     Perry South
# 3                            302 302 Warrant  Zone 3  2902.0         Carrick
# 4     18 2706 A1 Terroristic Threats-General  Zone 2   203.0  Strip District
#
#   ArrestCharge_Felony_Misdemeanor_Description   XCOORD   YCOORD  \
# 0                            MISDEMEANOR - M2 -79.9332  40.4054
# 1                            MISDEMEANOR - M2 -79.9332  40.4054
# 2                                         NaN -80.0078  40.4718
# 3                                         NaN -79.9831  40.4012
# 4                            MISDEMEANOR - M1 -79.9723  40.4639
#
#                                        Block_Address
# 0           700 BLOCK OF JOHNSTON AVE PITTSBURGH, PA
# 1           700 BLOCK OF JOHNSTON AVE PITTSBURGH, PA
# 2  2600 BLOCK OF MAPLE AVE, PITTSBURGH 15214 PITT...
# 3            1500 BLOCK OF TRANSVERSE PITTSBURGH, PA
# 4                                                NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# Given arrest data by WPRDC

# %%
violent_keywords = ["ASSAULT", "HOMICIDE", "ROBBERY", "RAPE"]

def get_weight(offense):
    offense = str(offense).upper()
    if any(word in offense for word in violent_keywords):
        return 3
    return 1

df["weight"] = df["NIBRS_Offense_Category"].apply(get_weight)

df['Neighborhood_Cleaned'] = df['Neighborhood'].str.strip().str.title()
mapping = {
    'St. Clair': 'Saint Clair', 
    'Chartiers': 'Chartiers City', 
    'Mt. Oliver': 'Mount Oliver', 
    'Mt Oliver': 'Mount Oliver'
}
df['Neighborhood_Cleaned'] = df['Neighborhood_Cleaned'].replace(mapping)

# %% [markdown]
# Converts an offense description to uppercase
# Checks if it contains a violent keyword
# Purpose is to check the severity of the crime

# %%
df.columns
# Out:
# Index(['_id', 'Template', 'Case_Number', 'ArrestPerson_ID', 'Arrest_Date',
#        'Arrest_Year', 'Arrest_Month', 'Arrest_Time', 'Type',
#        'ArrestPerson_Age', 'ArrestPerson_Sex', 'ArrestPerson_Race',
#        'NIBRS_Coded_Offense', 'NIBRS_Offense_Code', 'NIBRS_Offense_Category',
#        'NIBRS_Offense_Type', 'NIBRS_Crime_Against', 'NIBRS_Offense_Grouping',
#        'Violation', 'Zone', 'Tract', 'Neighborhood',
#        'ArrestCharge_Felony_Misdemeanor_Description', 'XCOORD', 'YCOORD',
#        'Block_Address', 'weight', 'Neighborhood_Cleaned'],
#       dtype='object')

# %%
neighborhood_scores_crime = df.groupby("Neighborhood")["weight"].sum().sort_values()

# %%
import matplotlib.pyplot as plt

top10_crime = neighborhood_scores_crime.head(10).reset_index()
top10_crime.columns = ["Neighborhood", "Safety Score"]

top10_crime

top10_crime.plot(kind="barh", x="Neighborhood", y="Safety Score", legend=False)
plt.gca().invert_yaxis()
plt.title("Top 10 Safest Neighborhoods (Crime)")
plt.xlabel("Safety Score")
plt.ylabel("Neighborhood")
plt.show()

# %% [markdown]
# Visualize which neighborhood is the safest from columns

# %%
import requests
import geopandas as gpd
from io import BytesIO

geo_url = "https://data.wprdc.org/dataset/e672f13d-71c4-4a66-8f38-710e75ed80a4/resource/4af8e160-57e9-4ebf-a501-76ca1b42fc99/download/neighborhoods.geojson"

response = requests.get(geo_url)

with open("neighborhoods.geojson", "wb") as f:
    f.write(response.content)

neighborhoods = gpd.read_file("neighborhoods.geojson")

# %%
neighborhoods.columns
# Out:
# Index(['OBJECTID', 'fid_blockg', 'statefp10', 'countyfp10', 'tractce10',
#        'blkgrpce10', 'geoid10', 'namelsad10', 'mtfcc10', 'funcstat10',
#        'aland10', 'awater10', 'intptlat10', 'intptlon10', 'shape_leng',
#        'fid_neighb', 'perimeter', 'neighbor_', 'neighbor_i', 'hood', 'hood_no',
#        'acres', 'sqmiles', 'dpwdiv', 'unique_id', 'sectors', 'shape_le_1',
#        'shape_ar_1', 'page_number', 'plannerassign', 'created_user',
#        'created_date', 'last_edited_user', 'last_edited_date', 'temp',
#        'pghdb_sde_Neighborhood_2010_are', 'GlobalID', 'Shape__Area',
#        'Shape__Length', 'geometry'],
#       dtype='object')

# %%
df["weight"] = df["NIBRS_Offense_Category"].apply(get_weight)

# %%
crime_scores = df.groupby("Neighborhood")["weight"].sum().reset_index()

# %%
crime_scores.columns = ["Neighborhood", "crime_score"]

# %%
neighborhoods.head()
# Out:
#    OBJECTID  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0         1         233        42        003    140500          3
# 1         2         203        42        003    140100          3
# 2         3          86        42        003    101700          2
# 3         4         214        42        003    050900          1
# 4         5         173        42        003    300100          5
#
#         geoid10     namelsad10 mtfcc10 funcstat10  ...  created_user  \
# 0  420031405003  Block Group 3   G5030          S  ...           SDE
# 1  420031401003  Block Group 3   G5030          S  ...           SDE
# 2  420031017002  Block Group 2   G5030          S  ...           SDE
# 3  420030509001  Block Group 1   G5030          S  ...           SDE
# 4  420033001005  Block Group 5   G5030          S  ...           SDE
#
#                created_date last_edited_user          last_edited_date  temp  \
# 0 2020-08-14 12:57:28+00:00              SDE 2020-08-14 13:02:13+00:00  None
# 1 2020-08-14 12:57:28+00:00              SDE 2020-08-14 13:02:41+00:00  None
# 2 2020-08-14 12:57:28+00:00              SDE 2020-08-14 12:59:55+00:00  None
# 3 2020-08-14 12:57:28+00:00              SDE 2020-08-14 12:58:41+00:00  None
# 4 2020-08-14 12:57:28+00:00              SDE 2020-08-14 13:00:19+00:00  None
#
#    pghdb_sde_Neighborhood_2010_are                              GlobalID  \
# 0                        7968760.0  a642a6b6-a2a9-48d5-acf2-3e2ce87d4bc0
# 1                       34078712.0  20d4605b-258e-441a-a57e-a28fdabb6d30
# 2                       12751163.0  bf4065e7-c29c-48bd-b529-e7fd99077238
# 3                        4997335.5  fed3fb32-0cd3-4556-aa41-17ee03b4fe41
# 4                        8411048.0  8669d2f0-b886-4519-99d0-bb1015b592b0
#
#     Shape__Area  Shape__Length  \
# 0  8.417067e+06   14181.728584
# 1  3.410837e+07   30326.819418
# 2  1.275115e+07   14577.426328
# 3  4.897519e+06   13941.514356
# 4  8.353046e+06   12021.860516
#
#                                             geometry
# 0  POLYGON ((-79.90531 40.45549, -79.90488 40.455...
# 1  POLYGON ((-79.92063 40.44423, -79.92052 40.443...
# 2  POLYGON ((-79.93546 40.47257, -79.9353 40.4725...
# 3  POLYGON ((-79.96601 40.4552, -79.96595 40.4548...
# 4  POLYGON ((-79.98819 40.41852, -79.98824 40.418...
#
# [5 rows x 40 columns]

# %%
crime_scores = df.groupby("Neighborhood")["weight"].sum().reset_index()

# %%
map_data = neighborhoods.merge(
    crime_scores,
    left_on="hood",
    right_on="Neighborhood",
    how="left"
)

# %%
neighborhood_scores = df.groupby("Neighborhood")["weight"].sum().sort_values()

# %%
neighborhood_scores.reset_index().columns
# Out:
# Index(['Neighborhood', 'weight'], dtype='object')

# %%
map_data.columns
# Out:
# Index(['OBJECTID', 'fid_blockg', 'statefp10', 'countyfp10', 'tractce10',
#        'blkgrpce10', 'geoid10', 'namelsad10', 'mtfcc10', 'funcstat10',
#        'aland10', 'awater10', 'intptlat10', 'intptlon10', 'shape_leng',
#        'fid_neighb', 'perimeter', 'neighbor_', 'neighbor_i', 'hood', 'hood_no',
#        'acres', 'sqmiles', 'dpwdiv', 'unique_id', 'sectors', 'shape_le_1',
#        'shape_ar_1', 'page_number', 'plannerassign', 'created_user',
#        'created_date', 'last_edited_user', 'last_edited_date', 'temp',
#        'pghdb_sde_Neighborhood_2010_are', 'GlobalID', 'Shape__Area',
#        'Shape__Length', 'geometry', 'Neighborhood', 'weight'],
#       dtype='object')

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 10))

map_data.plot(
    column="weight", 
    cmap="Greens_r",
    legend=True,
    missing_kwds={"color": "lightgrey"},
    ax=ax
)

plt.title("Neighborhood Safety Map (Lower = Better)")
plt.axis("off")
plt.show()

# %%
map_data.columns
# Out:
# Index(['OBJECTID', 'fid_blockg', 'statefp10', 'countyfp10', 'tractce10',
#        'blkgrpce10', 'geoid10', 'namelsad10', 'mtfcc10', 'funcstat10',
#        'aland10', 'awater10', 'intptlat10', 'intptlon10', 'shape_leng',
#        'fid_neighb', 'perimeter', 'neighbor_', 'neighbor_i', 'hood', 'hood_no',
#        'acres', 'sqmiles', 'dpwdiv', 'unique_id', 'sectors', 'shape_le_1',
#        'shape_ar_1', 'page_number', 'plannerassign', 'created_user',
#        'created_date', 'last_edited_user', 'last_edited_date', 'temp',
#        'pghdb_sde_Neighborhood_2010_are', 'GlobalID', 'Shape__Area',
#        'Shape__Length', 'geometry', 'Neighborhood', 'weight'],
#       dtype='object')

# %% [markdown]
# Saftey score is now attatched to a map given from previous data in this metric. In conclusion, Chartiers city seems to be the safest neigborhood within crime in our metric according to arrest reports.

# %% [markdown]
# # Metric #2: Housing Violations reports

# %%
from IPython.display import Image, display

url = "https://ap.rdcpix.com/bc8d1681e0a6b43ee43815fbcda0772cl-m740192753od-w480_h360_x2.jpg"

display(Image(url=url))
# Out:
# <img src="https://ap.rdcpix.com/bc8d1681e0a6b43ee43815fbcda0772cl-m740192753od-w480_h360_x2.jpg"/>

# %%
df.columns
# Out:
# Index(['_id', 'Template', 'Case_Number', 'ArrestPerson_ID', 'Arrest_Date',
#        'Arrest_Year', 'Arrest_Month', 'Arrest_Time', 'Type',
#        'ArrestPerson_Age', 'ArrestPerson_Sex', 'ArrestPerson_Race',
#        'NIBRS_Coded_Offense', 'NIBRS_Offense_Code', 'NIBRS_Offense_Category',
#        'NIBRS_Offense_Type', 'NIBRS_Crime_Against', 'NIBRS_Offense_Grouping',
#        'Violation', 'Zone', 'Tract', 'Neighborhood',
#        'ArrestCharge_Felony_Misdemeanor_Description', 'XCOORD', 'YCOORD',
#        'Block_Address', 'weight'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://data.wprdc.org/datastore/dump/70c06278-92c5-4040-ab28-17671866f81c"
df = pd.read_csv(url)

df.head()
# Out:
#        _id     casefile_number                                 address  \
# 0  8590660  CF-PLI-2023-025162  118 E AGNEW AVE, Pittsburgh, PA 15210-
# 1  8590661  CF-PLI-2023-025162  118 E AGNEW AVE, Pittsburgh, PA 15210-
# 2  8590662  CF-PLI-2023-025162  118 E AGNEW AVE, Pittsburgh, PA 15210-
# 3  8590663  CF-PLI-2023-025162  118 E AGNEW AVE, Pittsburgh, PA 15210-
# 4  8590664  CF-PLI-2023-025162  118 E AGNEW AVE, Pittsburgh, PA 15210-
#
#           parcel_id  status   case_file_type investigation_date  \
# 0  0060S00244000000  Closed  Broken Sidewalk         2023-09-21
# 1  0060S00244000000  Closed  Broken Sidewalk         2023-08-17
# 2  0060S00244000000  Closed  Broken Sidewalk         2023-09-19
# 3  0060S00244000000  Closed  Broken Sidewalk         2023-07-21
# 4  0060S00244000000  Closed  Broken Sidewalk                NaN
#
#     investigation_outcome                         investigation_findings  \
# 0      Violation Resolved               Violations have been corrected.
# 1         Violation Found                              Violation remains
# 2  Filing Court Paperwork  Violations remain until permit is completed.
# 3         Violation Found                   Violations have been cited.
# 4                     NaN                                            NaN
#
#                                violation_description  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4  Sidewalks, walkways, stairs, driveways, parkin...  ...
#
#                          violation_spec_instructions court_date court_time  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4  Repair or replace the sidewalk where it has br...        NaN        NaN
#
#   docket_number court_decision   latitude  longitude neighborhood  ward  \
# 0           NaN            NaN  40.395387 -79.985248      Carrick  29.0
# 1           NaN            NaN  40.395387 -79.985248      Carrick  29.0
# 2           NaN            NaN  40.395387 -79.985248      Carrick  29.0
# 3           NaN            NaN  40.395387 -79.985248      Carrick  29.0
# 4           NaN            NaN  40.395387 -79.985248      Carrick  29.0
#
#    council_district
# 0               4.0
# 1               4.0
# 2               4.0
# 3               4.0
# 4               4.0
#
# [5 rows x 23 columns]

# %%
df["violation_score"] = 1

# %%
neighborhood_scores_pli = df.groupby("neighborhood")["violation_score"].sum().sort_values()

# %%
df["violation_score"] = 1

neighborhood_scores = df.groupby("neighborhood")["violation_score"].sum().sort_values()

# %%
top10_pli = neighborhood_scores_pli.head(10).reset_index()
top10_pli.columns = ["Neighborhood", "Violation Score"]

top10_pli  # optional display

top10_pli.plot(kind="barh", x="Neighborhood", y="Violation Score", legend=False)
plt.gca().invert_yaxis()
plt.title("Top 10 Neighborhoods (Fewest PLI Violations)")
plt.xlabel("Violation Score")
plt.ylabel("Neighborhood")
plt.show()

# %% [markdown]
# Clean dataset of of violations for visualization up above

# %%
top10 = neighborhood_scores_pli.head(10).reset_index()
top10.columns = ["Neighborhood", "Violation Score"]

# %%
import matplotlib.pyplot as plt

top10.plot(
    kind="barh",
    x="Neighborhood",
    y="Violation Score",
    legend=False
)

plt.gca().invert_yaxis()
plt.title("Top 10 Neighborhoods (Fewest PLI Violations)")
plt.show()

# %% [markdown]
# Visually shows which neighborhood has fewest violations. Arlington Heights has fewest violations in the chart according to the data we were given.

# %% [markdown]
# Metric #3

# %% [markdown]
# ***Personally, I believe Ridgemont is the safest neighborhood in Pittsburgh. Though it didn't come first in any of my metrics, It still ranked high in both of them. A quick side not, although it isn't what I was looking for, it occured to me that New Homestead seems to be one of the worst neighborhoods according to my data. I've also done work outside of the classroom, and my friend from Pittsburgh says it isn't a safe neighborhood. P.S, sorry to anyone from New Homestead***

# %% [markdown]
# Conclusion
